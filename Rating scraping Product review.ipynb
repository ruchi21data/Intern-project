# %%
# Importing Libraries
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %%
#oening web driver and website
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

url = "https://www.amazon.in/HP-Pavilion-Graphics-Keyboard-14-dv0054TU/product-reviews/B08WBB369L/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"
driver.get(url)

# %%
#scraping reviews and rating from amazon 
stars = []
reviews_ = []
page_no = 1

while (page_no <45):
    reviews=driver.find_elements_by_xpath("//div[@class='a-section celwidget']")
    for review in reviews:
        try:
            star = review.find_elements_by_xpath(".//a[@class='a-link-normal']")[0].get_attribute('title')
            stars.append(star)
        except:
            stars.append("-")
        try:
            review_text =  review.find_element_by_xpath(".//span[@data-hook='review-body']").text
            reviews_.append(review_text)
        except:
            reviews_.append('-')
    page_no += 1
    try:
        next_page = driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute('href')
        driver.get(next_page)
    except:
        break

# %%
len(reviews_)
# Out:
# 372

# %%
# Make dataframe
df = pd.DataFrame({'Reviews':reviews_,'Ratings':stars})
df
# Out:
#                                                Reviews             Ratings
# 0    Received this yesterday (04/03/2021). Prompt d...  4.0 out of 5 stars
# 1    Different charger was sent in the box by Amazo...  1.0 out of 5 stars
# 2    Amazing laptop.. I ordered this laptop on its ...  5.0 out of 5 stars
# 3    As soon as I found 11gen Gen i5 at ~62K I got ...  4.0 out of 5 stars
# 4    Your browser does not support HTML5 video.\n D...  1.0 out of 5 stars
# ..                                                 ...                 ...
# 367  Laptop is good but Battery gives 2 to 3 hours ...  3.0 out of 5 stars
# 368                                                     5.0 out of 5 stars
# 369                   Nice product in this price range  5.0 out of 5 stars
# 370  It's a good laptops. specs are good .. Ryzen 5...  5.0 out of 5 stars
# 371  Very good product in this budget\nReally ossom...  5.0 out of 5 stars
#
# [372 rows x 2 columns]

# %%
#saving as CSV file
df.to_csv('REV1.csv',index=False)

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

url = "https://www.amazon.in/Redmi-10-Prime-extendable-Adaptive/product-reviews/B09CTYGJSD/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"
driver.get(url)

# %%
#scraping reviews and rating from amazon 
stars = []
reviews_ = []
page_no = 1

while (page_no <100):
    reviews=driver.find_elements_by_xpath("//div[@class='a-section celwidget']")
    for review in reviews:
        try:
            star = review.find_elements_by_xpath(".//a[@class='a-link-normal']")[0].get_attribute('title')
            stars.append(star)
        except:
            stars.append("-")
        try:
            review_text =  review.find_element_by_xpath(".//span[@data-hook='review-body']").text
            reviews_.append(review_text)
        except:
            reviews_.append('-')
    page_no += 1
    try:
        next_page = driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute('href')
        driver.get(next_page)
    except:
        break

# %%
len(stars)
# Out:
# 990

# %%
# Make dataframe
df1 = pd.DataFrame({'Reviews':reviews_,'Ratings':stars})
df1
# Out:
#                                                Reviews             Ratings
# 0                                 Front camara worrest  1.0 out of 5 stars
# 1                                 Don't buy this phone  1.0 out of 5 stars
# 2                                                       4.0 out of 5 stars
# 3                                                       1.0 out of 5 stars
# 4    Got an a used device, and camera is horrible, ...  1.0 out of 5 stars
# ..                                                 ...                 ...
# 985  Poor camera.\nBattery is okay\nDisplay is okay...  3.0 out of 5 stars
# 986  Camara is not like 48 mp don't purchase it. Th...  1.0 out of 5 stars
# 987  Mind blowing good product Very Good camera and...  5.0 out of 5 stars
# 988  Mi ka ab tak ka sabse bekar phone hai bhai log...  1.0 out of 5 stars
# 989  Buying this phone is really worth of money .Th...  5.0 out of 5 stars
#
# [990 rows x 2 columns]

# %%
#saving as CSV file
df1.to_csv('REV2.csv',index=False)

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

url = "https://www.amazon.in/Apple-iPad-Mini-Wi-Fi-64GB/product-reviews/B07PWXFPJY/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"
driver.get(url)

# %%
#scraping reviews and rating from amazon 
stars = []
reviews_ = []
page_no = 1

while (page_no <100):
    reviews=driver.find_elements_by_xpath("//div[@class='a-section celwidget']")
    for review in reviews:
        try:
            star = review.find_elements_by_xpath(".//a[@class='a-link-normal']")[0].get_attribute('title')
            stars.append(star)
        except:
            stars.append("-")
        try:
            review_text =  review.find_element_by_xpath(".//span[@data-hook='review-body']").text
            reviews_.append(review_text)
        except:
            reviews_.append('-')
    page_no += 1
    try:
        next_page = driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute('href')
        driver.get(next_page)
    except:
        break

# %%
len(stars)
# Out:
# 549

# %%
# Make dataframe
df2 = pd.DataFrame({'Reviews':reviews_,'Ratings':stars})
df2
# Out:
#                                                Reviews             Ratings
# 0    Apr 17: >>>>Ordered\nApr 18: >>>>Out for deliv...  5.0 out of 5 stars
# 1    Received this iPad Mini on the 20th of April, ...  5.0 out of 5 stars
# 2    The best smaller size tablet available in the ...  5.0 out of 5 stars
# 3    Its been three days with this Ipad now and I’m...  5.0 out of 5 stars
# 4    This is the tab I was looking for! After wasti...  5.0 out of 5 stars
# ..                                                 ...                 ...
# 544  Superb I got this as gift to my brother and he...  5.0 out of 5 stars
# 545  Received ipad mini5 from appario retailor(thou...  4.0 out of 5 stars
# 546  This is a poweehouse . I bought this thing onl...  5.0 out of 5 stars
# 547         Unbelievable gaming performance under 35k.  5.0 out of 5 stars
# 548  It's very nice product super screen quality an...  5.0 out of 5 stars
#
# [549 rows x 2 columns]

# %%
#saving as CSV file
df2.to_csv('REV4.csv',index=False)

# %%
#oening driver and url
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

url = "https://www.amazon.in/Redmi-10-Prime-extendable-Adaptive/product-reviews/B09CTYGJSD/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews"
driver.get(url)

# %%
#scraping reviews and rating
stars = []
reviews_ = []
page_no = 1

while (page_no <25):
    reviews=driver.find_elements_by_xpath("//div[@class='a-section celwidget']")
    for review in reviews:
        try:
            star = review.find_elements_by_xpath(".//a[@class='a-link-normal']")[0].get_attribute('title')
            stars.append(star)
        except:
            stars.append("-")
        try:
            review_text =  review.find_element_by_xpath(".//span[@data-hook='review-body']").text
            reviews_.append(review_text)
        except:
            reviews_.append('-')
    page_no += 1
    try:
        next_page = driver.find_element_by_xpath("//li[@class='a-last']/a").get_attribute('href')
        driver.get(next_page)
    except:
        break

# %%
# Make dataframe
df3 = pd.DataFrame({'Reviews':reviews_,'Ratings':stars})
df3
# Out:
#                                                Reviews             Ratings
# 0                                 Front camara worrest  1.0 out of 5 stars
# 1                                 Don't buy this phone  1.0 out of 5 stars
# 2                                                       4.0 out of 5 stars
# 3                                                       1.0 out of 5 stars
# 4    Got an a used device, and camera is horrible, ...  1.0 out of 5 stars
# ..                                                 ...                 ...
# 235  Good phone but at this price range you will ge...  4.0 out of 5 stars
# 236                                average phone\ngood  4.0 out of 5 stars
# 237  Front camera doesn't produce satisfactory imag...  2.0 out of 5 stars
# 238  I will never buy a mi phone after this one.. V...  1.0 out of 5 stars
# 239  Battery was amazing\nCamera prize ke hissab se...  4.0 out of 5 stars
#
# [240 rows x 2 columns]

# %%
#saving as CSV file
df3.to_csv('REV3.csv',index=False)
